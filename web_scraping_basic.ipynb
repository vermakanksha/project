# %%
#import the library used to query a website
import requests
#import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup
#import pandas to convert list to data frame
import pandas as pd

# %% [markdown]
# # Web Scrapping Basic

# %% [markdown]
# ## Wikipedia-List of states

# %% [markdown]
# ### web scrapping through beautifulsoup library for secured website

# %%
#specify the url
wiki = "https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India"

# %%
webpage = requests.get(wiki)

# %%
#Parse the html in the 'webpage' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(webpage.text,'lxml')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of state and union territory capitals in India - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
right_table=soup.find('table', class_='wikitable sortable plainrowheaders')
right_table
# Out:
# <table class="wikitable sortable plainrowheaders">
# <tr>
# <th scope="col">No.</th>
# <th scope="col">State or<br/>
# union territory</th>
# <th scope="col">Administrative capitals</th>
# <th scope="col">Legislative capitals</th>
# <th scope="col">Judiciary capitals</th>
# <th scope="col">Year capital was established</th>
# <th scope="col">The Former capital</th>
# </tr>
# <tr>
# <td>1</td>
# <th scope="row"><a href="/wiki/Andaman_and_Nicobar_Islands" title="Andaman and Nicobar Islands">Andaman and Nicobar Islands</a> <img alt="union territory" data-file-height="14" data-file-width="9" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/></th>
# <td><b><a href="/wiki/Port_Blair" title="Port Blair">Port Blair</a></b></td>
# <td>Port Blair</td>
# <td><a href="/wiki/Kolkata" title="Kolkata">Kolkata</a></td>
# <td>1955</td>
# <td>Calcutta (1945–1955)</td>
# </tr>
# <tr>
# <td>2</td>
# ...

# %%
#Generate lists
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]
for row in right_table.findAll("tr"):
    cells = row.findAll('td')
    states = row.findAll('th') #To store second column data
    if len(cells)==6: #Only extract table body not heading
        A.append(cells[0].find(text=True))
        B.append(states[0].find(text=True))
        C.append(cells[1].find(text=True))
        D.append(cells[2].find(text=True))
        E.append(cells[3].find(text=True))
        F.append(cells[4].find(text=True))
        G.append(cells[5].find(text=True))

# %%
E
# Out:
# ['Kolkata',
#  'Hyderabad',
#  'Guwahati',
#  'Guwahati',
#  'Patna',
#  'Chandigarh',
#  'Bilaspur',
#  'Mumbai',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'Ahmedabad',
#  'Chandigarh',
#  'Shimla\xa0',
#  'Srinagar\xa0(Summer)',
#  'Ranchi',
#  'Bengaluru',
#  'Kochi',
#  'Kochi',
#  'Jabalpur',
#  'Mumbai',
#  'Imphal',
#  'Shillong',
#  'Guwahati',
#  'Guwahati',
#  'Cuttack',
#  'Chennai',
#  'Jodhpur',
#  'Gangtok',
#  'Chennai',
#  'Hyderabad',
#  'Agartala',
#  'Allahabad',
#  'Nainital',
#  'Kolkata']

# %%
#converting list to dataframe
df=pd.DataFrame(A,columns=['Number'])
df['State/UT']=B
df['Admin_Capital']=C
df['Legislative_Capital']=D
df['Judiciary_Capital']=E
df['Year_Capital']=F
df['Former_Capital']=G

# %%
df
# Out:
#    Number                             State/UT       Admin_Capital  \
# 0       1          Andaman and Nicobar Islands          Port Blair
# 1       2                       Andhra Pradesh           Hyderabad
# 2       3                    Arunachal Pradesh            Itanagar
# 3       4                                Assam              Dispur
# 4       5                                Bihar               Patna
# 5       6                           Chandigarh          Chandigarh
# 6       7                         Chhattisgarh         Naya Raipur
# 7       8               Dadra and Nagar Haveli            Silvassa
# 8       9                        Daman and Diu               Daman
# 9      10  National Capital Territory of Delhi           New Delhi
# 10     11                                  Goa              Panaji
# 11     12                              Gujarat         Gandhinagar
# 12     13                              Haryana          Chandigarh
# ...

# %% [markdown]
# ## IMDb movie rating

# %% [markdown]
# ### web scrapping through pandas library for non-secured website

# %%
df = pd.read_html('http://www.imdb.com/india/top-rated-indian-movies/')

# %%
df
# Out:
# [     Unnamed: 0                               Rank & Title  IMDb Rating  \
#  0           NaN                          1.  Anand  (1971)          8.7
#  1           NaN                       2.  Drishyam  (2013)          8.6
#  2           NaN                        3.  Nayakan  (1987)          8.6
#  3           NaN                     4.  Anbe Sivam  (2003)          8.5
#  4           NaN                       5.  Gol Maal  (1979)          8.5
#  5           NaN                         6.  Dangal  (2016)          8.5
#  6           NaN                   7.  Black Friday  (2004)          8.5
#  7           NaN               8.  Taare Zameen Par  (2007)          8.4
#  8           NaN             9.  Jaane Bhi Do Yaaro  (1983)          8.4
#  9           NaN                      10.  3 Idiots  (2009)          8.4
#  10          NaN               11.  Pather Panchali  (1955)          8.3
#  11          NaN                 12.  Chupke Chupke  (1975)          8.3
# ...

# %%
table = df[0]

# %%
table
# Out:
#      Unnamed: 0                               Rank & Title  IMDb Rating  \
# 0           NaN                          1.  Anand  (1971)          8.7
# 1           NaN                       2.  Drishyam  (2013)          8.6
# 2           NaN                        3.  Nayakan  (1987)          8.6
# 3           NaN                     4.  Anbe Sivam  (2003)          8.5
# 4           NaN                       5.  Gol Maal  (1979)          8.5
# 5           NaN                         6.  Dangal  (2016)          8.5
# 6           NaN                   7.  Black Friday  (2004)          8.5
# 7           NaN               8.  Taare Zameen Par  (2007)          8.4
# 8           NaN             9.  Jaane Bhi Do Yaaro  (1983)          8.4
# 9           NaN                      10.  3 Idiots  (2009)          8.4
# 10          NaN               11.  Pather Panchali  (1955)          8.3
# 11          NaN                 12.  Chupke Chupke  (1975)          8.3
# ...

# %%
IMDb_rating = table.iloc[:,[1,2]]

# %%
IMDb_rating
# Out:
#                                   Rank & Title  IMDb Rating
# 0                            1.  Anand  (1971)          8.7
# 1                         2.  Drishyam  (2013)          8.6
# 2                          3.  Nayakan  (1987)          8.6
# 3                       4.  Anbe Sivam  (2003)          8.5
# 4                         5.  Gol Maal  (1979)          8.5
# 5                           6.  Dangal  (2016)          8.5
# 6                     7.  Black Friday  (2004)          8.5
# 7                 8.  Taare Zameen Par  (2007)          8.4
# 8               9.  Jaane Bhi Do Yaaro  (1983)          8.4
# 9                        10.  3 Idiots  (2009)          8.4
# 10                11.  Pather Panchali  (1955)          8.3
# 11                  12.  Chupke Chupke  (1975)          8.3
# 12                   13.  Vikram Vedha  (2017)          8.3
# 13                     14.  Thalapathi  (1991)          8.3
# 14              15.  Khosla Ka Ghosla!  (2006)          8.3
# ...
